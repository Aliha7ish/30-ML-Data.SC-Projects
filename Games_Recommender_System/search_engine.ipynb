# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import time
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MultiLabelBinarizer

# %%
# Text preprocessing functions
def text_preprocessing(text):
    """Remove special characters, lowercase, and normalize spaces."""
    if pd.isna(text):
        return ""
    # Remove special characters
    text = re.sub(r'[^\w\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    # Normalize whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
platforms_meta_api = "https://api.rawg.io/api/platforms?key=f65a6008ebf44d2face1535b1518c4f3"
r_games = requests.get(platforms_meta_api)

json_platforms_data = r_games.json()

# %%
# Explore json file
for key,value in json_platforms_data.items():
    print(f"{key} : {value}")
# Out:
# count : 51
# next : https://api.rawg.io/api/platforms?key=f65a6008ebf44d2face1535b1518c4f3&page=2
# previous : None
# results : [{'id': 4, 'name': 'PC', 'slug': 'pc', 'games_count': 547965, 'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg', 'image': None, 'year_start': None, 'year_end': None, 'games': [{'id': 3498, 'slug': 'grand-theft-auto-v', 'name': 'Grand Theft Auto V', 'added': 21980}, {'id': 3328, 'slug': 'the-witcher-3-wild-hunt', 'name': 'The Witcher 3: Wild Hunt', 'added': 21620}, {'id': 4200, 'slug': 'portal-2', 'name': 'Portal 2', 'added': 20516}, {'id': 4291, 'slug': 'counter-strike-global-offensive', 'name': 'Counter-Strike: Global Offensive', 'added': 18240}, {'id': 5286, 'slug': 'tomb-raider', 'name': 'Tomb Raider (2013)', 'added': 17564}, {'id': 13536, 'slug': 'portal', 'name': 'Portal', 'added': 17484}]}, {'id': 187, 'name': 'PlayStation 5', 'slug': 'playstation5', 'games_count': 1244, 'image_background': 'https://media.rawg.io/media/games/34b/34b1f1850a1c06fd971bc6ab3ac0ce0e.jpg', 'image': None, 'year_start': 2020, 'year_end': None, 'games': [{'id': 3498, 'slug': 'grand-theft-auto-v', 'name': 'Grand Theft Auto V', 'added': 21980}, {'id': 3328, 'slug': 'the-witcher-3-wild-hunt', 'name': 'The Witcher 3: Wild Hunt', 'added': 21620}, {'id': 5679, 'slug': 'the-elder-scrolls-v-skyrim', 'name': 'The Elder Scrolls V: Skyrim', 'added': 16504}, {'id': 32, 'slug': 'destiny-2', 'name': 'Destiny 2', 'added': 14510}, {'id': 3070, 'slug': 'fallout-4', 'name': 'Fallout 4', 'added': 14067}, {'id': 41494, 'slug': 'cyberpunk-2077', 'name': 'Cyberpunk 2077', 'added': 13523}]}, {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one', 'games_count': 5696, 'image_background': 'https://media.rawg.io/media/games/021/021c4e21a1824d2526f925eff6324653.jpg', 'image': None, 'year_start': None, 'year_end': None, 'games': [{'id': 3498, 'slug': 'grand-theft-auto-v', 'name': 'Grand Theft Auto V', 'added': 21980}, {'id': 3328, 'slug': 'the-witcher-3-wild-hunt', 'name': 'The Witcher 3: Wild Hunt', 'added': 21620}, {'id': 4200, 'slug': 'portal-2', 'name': 'Portal 2', 'added': 20516}, {'id': 5286, 'slug': 'tomb-raider', 'name': 'Tomb Raider (2013)', 'added': 17564}, {'id': 5679, 'slug': 'the-elder-scrolls-v-skyrim', 'name': 'The Elder Scrolls V: Skyrim', 'added': 16504}, {'id': 28, 'slug': 'red-dead-redemption-2', 'name': 'Red Dead Redemption 2', 'added': 16297}]}, {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'games_count': 6919, 'image_background': 'https://media.rawg.io/media/games/d1a/d1a2e99ade53494c6330a0ed945fe823.jpg', 'image': None, 'year_start': None, 'year_end': None, 'games': [{'id': 3498, 'slug': 'grand-theft-auto-v', 'name': 'Grand Theft Auto V', 'added': 21980}, {'id': 3328, 'slug': 'the-witcher-3-wild-hunt', 'name': 'The Witcher 3: Wild Hunt', 'added': 21620}, {'id': 5286, 'slug': 'tomb-raider', 'name': 'Tomb Raider (2013)', 'added': 17564}, {'id': 5679, 'slug': 'the-elder-scrolls-v-skyrim', 'name': 'The Elder Scrolls V: Skyrim', 'added': 16504}, {'id': 28, 'slug': 'red-dead-redemption-2', 'name': 'Red Dead Redemption 2', 'added': 16297}, {'id': 4062, 'slug': 'bioshock-infinite', 'name': 'BioShock Infinite', 'added': 15901}]}, {'id': 186, 'name': 'Xbox Series S/X', 'slug': 'xbox-series-x', 'games_count': 1079, 'image_background': 'https://media.rawg.io/media/games/618/618c2031a07bbff6b4f611f10b6bcdbc.jpg', 'image': None, 'year_start': 2020, 'year_end': None, 'games': [{'id': 3498, 'slug': 'grand-theft-auto-v', 'name': 'Grand Theft Auto V', 'added': 21980}, {'id': 3328, 'slug': 'the-witcher-3-wild-hunt', 'name': 'The Witcher 3: Wild Hunt', 'added': 21620}, {'id': 5679, 'slug': 'the-elder-scrolls-v-skyrim', 'name': 'The Elder Scrolls V: Skyrim', 'added': 16504}, {'id': 32, 'slug': 'destiny-2', 'name': 'Destiny 2', 'added': 14510}, {'id': 41494, 'slug': 'cyberpunk-2077', 'name': 'Cyberpunk 2077', 'added': 13523}, {'id': 766, 'slug': 'warframe', 'name': 'Warframe', 'added': 13065}]}, {'id': 7, 'name': 'Nintendo Switch', 'slug': 'nintendo-switch', 'games_count': 5626, 'image_background': 'https://m ...

# %% [markdown]
# ## Player Data

# %%
# load users data
users_df = pd.read_csv("../data/users_pref.csv")

# prin first few rows
users_df.head()
# Out:
#    151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 0  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 1  151603712                   Fallout 4  purchase    1.0  0
# 2  151603712                   Fallout 4      play   87.0  0
# 3  151603712                       Spore  purchase    1.0  0
# 4  151603712                       Spore      play   14.9  0

# %%
# rename columns
users_df.columns = ["user_id", "game_name", "behavior", "playtime", "unknown"]
# drop last column
users_df.drop(columns = ["unknown"], inplace = True)
# display quick info
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    199999 non-null  int64
#  1   game_name  199999 non-null  object
#  2   behavior   199999 non-null  object
#  3   playtime   199999 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.1+ MB

# %%
# Clean game title
users_df["game_name_mod"] = users_df["game_name"].apply(text_preprocessing)
# remove games with 0 chars
users_df = users_df[users_df["game_name_mod"].str.len() > 0]
# convert Game Name Cleanded col to category
users_df["game_name_mod"] = users_df["game_name_mod"].astype("category")

# create new columns
users_df["purchase"] = users_df["behavior"].apply(lambda x: 1 if x == "purchase" or x == "play" else 0)
users_df["play"] = users_df["playtime"].apply(lambda x: 1 if x > 1 else 0)
users_df["hours_played"] = users_df["playtime"].apply(lambda x: 1 if x == 1 else x)

# display rows
users_df.head()
# Out:
#      user_id                   game_name  behavior  playtime  \
# 0  151603712  The Elder Scrolls V Skyrim      play     273.0
# 1  151603712                   Fallout 4  purchase       1.0
# 2  151603712                   Fallout 4      play      87.0
# 3  151603712                       Spore  purchase       1.0
# 4  151603712                       Spore      play      14.9
#
#                 game_name_mod  purchase  play  hours_played
# 0  the elder scrolls v skyrim         1     1         273.0
# 1                   fallout 4         1     0           1.0
# 2                   fallout 4         1     1          87.0
# 3                       spore         1     0           1.0
# 4                       spore         1     1          14.9

# %%
# drop columns
users_df.drop(columns = ["behavior", "playtime"], inplace = True)
users_df.head()
# Out:
#      user_id                   game_name               game_name_mod  \
# 0  151603712  The Elder Scrolls V Skyrim  the elder scrolls v skyrim
# 1  151603712                   Fallout 4                   fallout 4
# 2  151603712                   Fallout 4                   fallout 4
# 3  151603712                       Spore                       spore
# 4  151603712                       Spore                       spore
#
#    purchase  play  hours_played
# 0         1     1         273.0
# 1         1     0           1.0
# 2         1     1          87.0
# 3         1     0           1.0
# 4         1     1          14.9

# %%
# Save cleaned dataframe for later use
users_df.to_csv("users_data.csv", index = False)

# %%
# unique games users had played
users_df["game_name_mod"].unique()
# Out:
# ['the elder scrolls v skyrim', 'fallout 4', 'spore', 'fallout new vegas', 'left 4 dead 2', ..., 'warriors castles', 'romance of the three kingdoms maker', 'space colony', 'life is hard', 'executive assault']
# Length: 5151
# Categories (5151, object): ['007 legends', '0rbitalis', '1 2 3 kick it drop that beat like an ugly baby', '10 second ninja', ..., 'zotrix', 'zuma deluxe', 'zumas revenge', 'zumas revenge adventure']

# %%
# top 20 played/purchased games
users_df["game_name_mod"].value_counts()[:20]
# Out:
# game_name_mod
# dota 2                            9682
# team fortress 2                   4646
# counterstrike global offensive    2789
# unturned                          2632
# left 4 dead 2                     1752
# counterstrike source              1693
# counterstrike                     1424
# garrys mod                        1397
# the elder scrolls v skyrim        1393
# warframe                          1271
# halflife 2 lost coast             1158
# sid meiers civilization v         1150
# robocraft                         1096
# halflife 2 deathmatch             1021
# portal                            1005
# portal 2                           997
# halflife 2                         995
# heroes generals                    993
# terraria                           956
# counterstrike condition zero       904
# Name: count, dtype: int64

# %% [markdown]
# ## Games Data

# %%
# get all platforms
games_meta_api = "https://api.rawg.io/api/platforms?key=f65a6008ebf44d2face1535b1518c4f3"
all_platforms = [] # adding all games to this list

while games_meta_api:
    response = requests.get(games_meta_api)
    data = response.json()
    all_platforms.extend(data["results"])  # Add platforms to the list
    games_meta_api = data.get("next")

print(f"We have total {len(all_platforms)} platform")
# Out:
# We have total 51 platform

# %%
platforms_list = [{
    "id": p["id"],
    "name": p["name"],
    "slug": p["slug"],
    "Games Count": p["games_count"],
    "Image": p["image_background"],
    "year_start": p["year_start"],
    "year_end": p["year_end"]
} for p in all_platforms]

# convert to dataframe
platforms_df = pd.DataFrame(platforms_list)

platforms_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           51 non-null     int64
#  1   name         51 non-null     object
#  2   slug         51 non-null     object
#  3   Games Count  51 non-null     int64
#  4   Image        51 non-null     object
#  5   year_start   2 non-null      float64
#  6   year_end     0 non-null      object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.9+ KB

# %%
top_platforms = platforms_df.sort_values(by="Games Count", ascending=False).head(5)
top_platforms
# Out:
#      id   name   slug  Games Count  \
# 0     4     PC     pc       547965
# 50  171    Web    web       260078
# 11    5  macOS  macos       106293
# 12    6  Linux  linux        78896
# 6     3    iOS    ios        77395
#
#                                                 Image  year_start year_end
# 0   https://media.rawg.io/media/games/fc1/fc1307a2...         NaN     None
# 50  https://media.rawg.io/media/screenshots/0e0/0e...         NaN     None
# 11  https://media.rawg.io/media/games/ec3/ec3a7db7...         NaN     None
# 12  https://media.rawg.io/media/games/f46/f466571d...         NaN     None
# 6   https://media.rawg.io/media/games/997/997ab4d6...         NaN     None

# %%
api_key = "f65a6008ebf44d2face1535b1518c4f3"
all_games = []

platform_ids = [4, 5, 6]  # fetch games from pc, macos and linux platforms

for platform_id in platform_ids:
    page = 1
    while True:
        params = {
            "key": api_key,
            "platforms": platform_id,
            "page_size": 40,
            "page": page
        }
        try:
            response = requests.get("https://api.rawg.io/api/games", params=params, timeout=5)
            response.raise_for_status()
            games = response.json().get("results", [])
            if not games:
                break

            for game in games:
                game_id = game["id"]

                # Fetch detailed info for each game
                detail_url = f"https://api.rawg.io/api/games/{game_id}"
                detail_params = {"key": api_key}
                try:
                    detail_resp = requests.get(detail_url, params=detail_params, timeout=10)
                    detail_resp.raise_for_status()
                    detail = detail_resp.json()

                    all_games.append({
                        "platform_id": platform_id,
                        "game_id": game_id,
                        "name": detail["name"],
                        "released": detail["released"],
                        "rating": detail["rating"],
                        "metacritic": detail.get("metacritic"),
                        "genres": ", ".join([g["name"] for g in detail.get("genres", [])]),
                        "tags": ", ".join([t["name"] for t in detail.get("tags", [])[:5]])
                    })

                    print(f"Fetched details for game ID: {game_id}")

                    time.sleep(1.5)  # Avoid rate limiting

                except requests.exceptions.RequestException as e:
                    print(f"Error fetching details for game ID {game_id}: {e}")
                    continue

            print(f"Platform {platform_id} - Page {page} done.")
            page += 1

        except requests.exceptions.RequestException as e:
            print(f"Error fetching game list for platform {platform_id} page {page}: {e}")
            break

games_df = pd.DataFrame(all_games)
print("Total detailed games fetched:", games_df.shape)
# Out:
# Fetched details for game ID: 3498
# Fetched details for game ID: 3328
# Fetched details for game ID: 4200
# Fetched details for game ID: 4291
# Fetched details for game ID: 5286
# Fetched details for game ID: 13536
# Fetched details for game ID: 12020
# Fetched details for game ID: 5679
# Fetched details for game ID: 28
# Fetched details for game ID: 4062
# Fetched details for game ID: 13537
# Fetched details for game ID: 802
# Fetched details for game ID: 3439
# Fetched details for game ID: 4286
# Fetched details for game ID: 32
# Fetched details for game ID: 58175
# Fetched details for game ID: 3070
# Fetched details for game ID: 3939
# Fetched details for game ID: 1030
# Fetched details for game ID: 11859
# Fetched details for game ID: 2454
# Fetched details for game ID: 41494
# Fetched details for game ID: 422
# Fetched details for game ID: 10213
# Fetched details for game ID: 766
# Fetched details for game ID: 4459
# Fetched details for game ID: 3272
# Fetched details for game ID: 278
# Fetched details for game ID: 29028
# Fetched details for game ID: 7689
# Fetched details for game ID: 3287
# Fetched details for game ID: 3192
# Fetched details for game ID: 290856
# Fetched details for game ID: 16944
# Fetched details for game ID: 17822
# Fetched details for game ID: 416
# Fetched details for game ID: 19103
# Fetched details for game ID: 11973
# Fetched details for game ID: 23027
# Fetched details for game ID: 9767
# Platform 4 - Page 1 done.
# Fetched details for game ID: 41
# Fetched details for game ID: 4427
# Fetched details for game ID: 18080
# Fetched details for game ID: 19710
# Fetched details for game ID: 11936
# Fetched details for game ID: 19709
# Fetched details for game ID: 2551
# Fetched details for game ID: 10754
# Fetched details for game ID: 10035
# Fetched details for game ID: 4252
# Fetched details for game ID: 3612
# Fetched details for game ID: 654
# Fetched details for game ID: 3790
# Fetched details for game ID: 1447
# Fetched details for game ID: 10142
# Fetched details for game ID: 10533
# Fetched details for game ID: 4161
# Fetched details for game ID: 9721
# Fetched details for game ID: 13668
# Fetched details for game ID: 11935
# Fetched details for game ID: 19487
# Fetched details for game ID: 3696
# Fetched details for game ID: 4332
# Fetched details for game ID: 4386
# Fetched details for game ID: 58134
# Fetched details for game ID: 29177
# Fetched details for game ID: 39
# Fetched details for game ID: 5563
# Fetched details for game ID: 4828
# Fetched details for game ID: 12447
# Fetched details for game ID: 9882
# Fetched details for game ID: 864
# Fetched details for game ID: 10243
# Fetched details for game ID: 17540
# Fetched details for game ID: 4248
# Fetched details for game ID: 12536
# Fetched details for game ID: 13633
# Fetched details for game ID: 5583
# Fetched details for game ID: 430
# Fetched details for game ID: 3144
# Platform 4 - Page 2 done.
# Fetched details for game ID: 362
# Fetched details for game ID: 4514
# Fetched details for game ID: 3841
# Fetched details for game ID: 58812
# Fetched details for game ID: 11934
# Fetched details for game ID: 257201
# Fetched details for game ID: 4570
# Fetched details for game ID: 4806
# Fetched details for game ID: 3017
# Fetched details for game ID: 3604
# Fetched details for game ID: 3543
# Fetched details for game ID: 19301
# Fetched details for game ID: 50738
# Fetched details for game ID: 13535
# Fetched details for game ID: 3603
# Fetched details for game ID: 11142
# Fetched details for game ID: 3747
# Fetched details for game ID: 108
# Fetched details for game ID: 11147
# Fetched details for game ID: 4513
# Fetched details for game ID: 10141
# Fetched details for game ID: 326292
# Fetched details for game ID: 274755
# Fetched details for game ID: 4166
# Fetched details for game ID: 46889
# Fetched details for game ID: 3191
# Fetched details for game ID: 613
# Fetched details for game ID: 10989
# Fetched details for game ID: 25
# Fetched details for game ID: 17576
# Fetched details for game ID: 9810
# Fetched details for game ID: 22509
# Fetched details for game ID: 480
# Fetched details for game ID: 10065
# Fetched details for game ID: 923
# Fetched details for game ID: 3254
# Fetched details for game ID: 17572
# Fetched details for game ID: 9743
# Fetched details for game ID: 45969
# Fetched details for game ID: 13910
# Platform 4 - Page 3 done.
# Fetched details for game ID: 13554
# Fetched details for game ID: 13627
# Fetched details for game ID: 28179
# Fetched details for game ID: 5525
# Fetched details for game ID: 18240
# Fetched details for game ID: 1416
# Fetched details for game ID: 23585
# Fetched details for game ID: 2361
# Fetched details for game ID: 51329
# Fetched details for game ID: 3687
# Fetched details for game ID: 28201
# Fetched details for game ID: 9830
# Fetched details for game ID: 2743
# Fetched details for game ID: 1450
# Fetched details for game ID: 3931
# Fetched details for game ID: 4280
# Fetched details for game ID: 50734
# Fetched details for game ID: 8488
# Fetched details for game ID: 2819
# Fetched details for game ID: 2093
# Fetched details for game ID: 4223
# Fetched details for game ID: 3556
# Fetched details for game ID: 58616
# Fetched details for game ID: 3678
# Fetched details for game ID: 58654
# Fetched details for game ID: 4502
# Fetched details for game ID: 11052
# Fetched details for game ID: 28154
# Fetched details for game ID: 28568
# Fetched details for game ID: 2235
# Fetched details for game ID: 262382
# Fetched details for game ID: 10340
# Fetched details for game ID: 356714
# Fetched details for game ID: 58777
# Fetched details for game ID: 58751
# Fetched details for game ID: 28153
# Fetched details for game ID: 326243
# Fetched details for game ID: 1010
# Fetched details for game ID: 2792
# Fetched details for game ID: 3876
# Platform 4 - Page 4 done.
# Fetched details for game ID: 4003
# Fetched details for game ID: 1682
# Fetched details for game ID: 998
# Fetched details for game ID: 18613
# Fetched details for game ID: 1256
# Fetched details for game ID: 13461
# Fetched details for game ID: 3497
# Fetched details for game ID: 17959
# Fetched details for game ID: 12024
# Fetched details for game ID: 15002
# Fetched details for game ID: 22571
# Fetched details for game ID: 13268
# Fetched details for game ID: 4599
# Fetched details for game ID: 10560
# Fetched details for game ID: 4527
# Fetched details for game ID: 11435
# Fetched details for game ID: 3853
# Fetched details for game ID: 10297
# Fetched details for game ID: 19590
# Fetched details for game ID: 3168
# Fetched details for game ID: 13305
# Fetched details for game ID: 28172
# Fetched details for game ID: 1090
# Fetched details for game ID: 4013
# Fetched details for game ID: 3766
# Fetched details for game ID: 17352
# Fetched details for game ID: 10061
# Fetched details for game ID: 952
# Fetched details for game ID: 432
# Fetched details for game ID: 4544
# Fetched details for game ID: 28202
# Fetched details for game ID: 906
# Fetched details for game ID: 43877
# Fetched details for game ID: 3474
# Fetched details for game ID: 18272
# Fetched details for game ID: 11726
# Fetched details for game ID: 1358
# Fetched details for game ID: 10548
# Fetched details for game ID: 10073
# Fetched details for game ID: 28492
# Platform 4 - Page 5 done.
# Fetched details for game ID: 559
# Fetched details for game ID: 3757
# Fetched details for game ID: 19542
# Fetched details for game ID: 10419
# Fetched details for game ID: 2572
# Fetched details for game ID: 3740
# Fetched details for game ID: 21265
# Fetched details for game ID: 4954
# Fetched details for game ID: 59359
# Fetched details for game ID: 1244
# Fetched details for game ID: 14348
# Fetched details for game ID: 15859
# Fetched details for game ID: 56184
# Fetched details for game ID: 857
# Fetched details for game ID: 9475
# Fetched details for game ID: 8146
# Fetched details for game ID: 3015
# Fetched details for game ID: 865
# Fetched details for game ID: 19384
# Fetched details for game ID: 4639
# Fetched details for game ID: 3486
# Fetched details for game ID: 18241
# Fetched details for game ID: 6617
# Fetched details for game ID: 3932
# Fetched details for game ID: 4550
# Fetched details for game ID: 16112
# Fetched details for game ID: 3771
# Fetched details for game ID: 17875
# Fetched details for game ID: 58755
# Fetched details for game ID: 5562
# Fetched details for game ID: 492
# Fetched details for game ID: 28623
# Fetched details for game ID: 817974
# Fetched details for game ID: 3028
# Fetched details for game ID: 17126
# Fetched details for game ID: 1169
# Fetched details for game ID: 29338
# Fetched details for game ID: 7819
# Fetched details for game ID: 1959
# Fetched details for game ID: 42187
# Platform 4 - Page 6 done.
# Fetched details for game ID: 3842
# Fetched details for game ID: 42
# Fetched details for game ID: 19365
# Fetched details for game ID: 3892
# Fetched details for game ID: 21924
# Fetched details for game ID: 1774
# Fetched details for game ID: 3408
# Fetched details for game ID: 5159
# Fetched details for game ID: 624
# Fetched details for game ID: 2733
# Fetched details for game ID: 2873
# Fetched details for game ID: 2623
# Fetched details for game ID: 16209
# Fetched details for game ID: 9609
# Fetched details for game ID: 28199
# Fetched details for game ID: 28559
# Fetched details for game ID: 9600
# Fetched details for game ID: 11686
# Fetched details for game ID: 23322
# Fetched details for game ID: 274762
# Fetched details for game ID: 11276
# Fetched details for game ID: 58753
# Fetched details for game ID: 15834
# Fetched details for game ID: 22781
# Fetched details for game ID: 16343
# Fetched details for game ID: 752
# Fetched details for game ID: 20406
# Fetched details for game ID: 3371
# Fetched details for game ID: 58617
# Fetched details for game ID: 4440
# Fetched details for game ID: 16113
# Fetched details for game ID: 13194
# Fetched details for game ID: 306124
# Fetched details for game ID: 18336
# Fetched details for game ID: 4101
# Fetched details for game ID: 2728
# Fetched details for game ID: 12756
# Fetched details for game ID: 4573
# Fetched details for game ID: 45821
# Fetched details for game ID: 14446
# Platform 4 - Page 7 done.
# Fetched details for game ID: 22121
# Fetched details for game ID: 14512
# Fetched details for game ID: 4094
# Fetched details for game ID: 15426
# Fetched details for game ID: 18614
# Fetched details for game ID: 9966
# Fetched details for game ID: 2597
# Fetched details for game ID: 30899
# Fetched details for game ID: 9671
# Fetched details for game ID: 2115
# Fetched details for game ID: 4123
# Fetched details for game ID: 42895
# Fetched details for game ID: 13913
# Fetched details for game ID: 13247
# Fetched details for game ID: 28152
# Fetched details for game ID: 17857
# Fetched details for game ID: 58550
# Fetched details for game ID: 46956
# Fetched details for game ID: 14962
# Fetched details for game ID: 18183
# Fetched details for game ID: 50778
# Fetched details for game ID: 19569
# Fetched details for game ID: 750
# Fetched details for game ID: 11312
# Fetched details for game ID: 5193
# Fetched details for game ID: 670682
# Fetched details for game ID: 14016
# Fetched details for game ID: 3368
# Fetched details for game ID: 250
# Fetched details for game ID: 2518
# Fetched details for game ID: 16359
# Fetched details for game ID: 274480
# Fetched details for game ID: 9653
# Fetched details for game ID: 3346
# Fetched details for game ID: 9793
# Fetched details for game ID: 17803
# Fetched details for game ID: 10449
# Fetched details for game ID: 13628
# Fetched details for game ID: 15858
# Fetched details for game ID: 12320
# Platform 4 - Page 8 done.
# Fetched details for game ID: 10092
# Fetched details for game ID: 50781
# Fetched details for game ID: 3554
# Fetched details for game ID: 17380
# Fetched details for game ID: 51610
# Fetched details for game ID: 19299
# Fetched details for game ID: 10090
# Fetched details for game ID: 15274
# Fetched details for game ID: 19451
# Fetched details for game ID: 12569
# Fetched details for game ID: 3427
# Fetched details for game ID: 3729
# Fetched details for game ID: 452638
# Fetched details for game ID: 3912
# Fetched details for game ID: 10001
# Fetched details for game ID: 14062
# Fetched details for game ID: 5161
# Fetched details for game ID: 829
# Fetched details for game ID: 3449
# Fetched details for game ID: 5578
# Fetched details for game ID: 678
# Fetched details for game ID: 14690
# Fetched details for game ID: 19452
# Fetched details for game ID: 4729
# Fetched details for game ID: 14317
# Fetched details for game ID: 3300
# Fetched details for game ID: 2574
# Fetched details for game ID: 17174
# Fetched details for game ID: 19375
# Fetched details for game ID: 58813
# Fetched details for game ID: 3697
# Fetched details for game ID: 2047
# Fetched details for game ID: 4179
# Fetched details for game ID: 455597
# Fetched details for game ID: 10064
# Fetched details for game ID: 53341
# Fetched details for game ID: 11974
# Fetched details for game ID: 12019
# Fetched details for game ID: 47137
# Fetched details for game ID: 2300
# Platform 4 - Page 9 done.
# Fetched details for game ID: 2166
# Fetched details for game ID: 295021
# Fetched details for game ID: 397477
# Fetched details for game ID: 442855
# Fetched details for game ID: 28121
# Fetched details for game ID: 4032
# Fetched details for game ID: 9551
# Fetched details for game ID: 442854
# Fetched details for game ID: 4000
# Fetched details for game ID: 10040
# Fetched details for game ID: 259801
# Fetched details for game ID: 295
# Fetched details for game ID: 3350
# Fetched details for game ID: 19600
# Fetched details for game ID: 9575
# Fetched details for game ID: 7381
# Fetched details for game ID: 2100
# Fetched details for game ID: 3290
# Fetched details for game ID: 3647
# Fetched details for game ID: 5565
# Fetched details for game ID: 5564
# Fetched details for game ID: 685577
# Fetched details for game ID: 23557
# Fetched details for game ID: 23587
# Fetched details for game ID: 17037
# Fetched details for game ID: 4882
# Fetched details for game ID: 6879
# Fetched details for game ID: 13820
# Fetched details for game ID: 12929
# Fetched details for game ID: 3052
# Fetched details for game ID: 10428
# Fetched details for game ID: 41490
# Fetched details for game ID: 3561
# Fetched details for game ID: 4869
# Fetched details for game ID: 28110
# Fetched details for game ID: 59313
# Fetched details for game ID: 16199
# Fetched details for game ID: 42215
# Fetched details for game ID: 248521
# Fetched details for game ID: 452649
# Platform 4 - Page 10 done.
# Fetched details for game ID: 3635
# Fetched details for game ID: 4397
# Fetched details for game ID: 58494
# Fetched details for game ID: 17885
# Fetched details for game ID: 719
# Fetched details for game ID: 19647
# Fetched details for game ID: 398423
# Fetched details for game ID: 704634
# Fetched details for game ID: 13886
# Fetched details for game ID: 19491
# Fetched details for game ID: 10293
# Fetched details for game ID: 892
# Fetched details for game ID: 4347
# Fetched details for game ID: 34
# Fetched details for game ID: 58764
# Fetched details for game ID: 4358
# Fetched details for game ID: 11279
# Fetched details for game ID: 29153
# Fetched details for game ID: 382
# Fetched details for game ID: 5342
# Fetched details for game ID: 58952
# Fetched details for game ID: 45970
# Fetched details for game ID: 15566
# Fetched details for game ID: 15829
# Fetched details for game ID: 1758
# Fetched details for game ID: 1259
# Fetched details for game ID: 44525
# Fetched details for game ID: 1789
# Fetched details for game ID: 19056
# Fetched details for game ID: 4581
# Fetched details for game ID: 3965
# Fetched details for game ID: 15642
# Fetched details for game ID: 10767
# Fetched details for game ID: 9631
# Fetched details for game ID: 58752
# Fetched details for game ID: 19057
# Fetched details for game ID: 622492
# Fetched details for game ID: 19592
# Fetched details for game ID: 5636
# Fetched details for game ID: 19410
# Platform 4 - Page 11 done.
# Fetched details for game ID: 616765
# Fetched details for game ID: 38
# Fetched details for game ID: 884
# Fetched details for game ID: 4439
# Fetched details for game ID: 1140
# Fetched details for game ID: 5528
# Fetched details for game ID: 3315
# Fetched details for game ID: 15317
# Fetched details for game ID: 14606
# Fetched details for game ID: 391399
# Fetched details for game ID: 10310
# Fetched details for game ID: 15714
# Fetched details for game ID: 326252
# Fetched details for game ID: 20405
# Fetched details for game ID: 5298
# Fetched details for game ID: 2805
# Fetched details for game ID: 197
# Fetched details for game ID: 9835
# Fetched details for game ID: 16787
# Fetched details for game ID: 14334
# Fetched details for game ID: 4523
# Fetched details for game ID: 326251
# Fetched details for game ID: 4012
# Fetched details for game ID: 17127
# Fetched details for game ID: 6773
# Fetched details for game ID: 29215
# Fetched details for game ID: 29171
# Fetched details for game ID: 58827
# Fetched details for game ID: 18003
# Fetched details for game ID: 11970
# Fetched details for game ID: 5297
# Fetched details for game ID: 4387
# Fetched details for game ID: 19196
# Fetched details for game ID: 437059
# Fetched details for game ID: 10615
# Fetched details for game ID: 17356
# Fetched details for game ID: 1670
# Fetched details for game ID: 4535
# Fetched details for game ID: 366850
# Fetched details for game ID: 52939
# Platform 4 - Page 12 done.
# Fetched details for game ID: 19429
# Fetched details for game ID: 4331
# Fetched details for game ID: 10031
# Fetched details for game ID: 28395
# Fetched details for game ID: 2213
# Fetched details for game ID: 42776
# Fetched details for game ID: 58133
# Fetched details for game ID: 13856
# Fetched details for game ID: 2255
# Fetched details for game ID: 327999
# Fetched details for game ID: 324997
# Fetched details for game ID: 58651
# Fetched details for game ID: 13079
# Fetched details for game ID: 204
# Fetched details for game ID: 4388
# Fetched details for game ID: 17252
# Fetched details for game ID: 452634
# Fetched details for game ID: 22859
# Fetched details for game ID: 2722
# Fetched details for game ID: 263590
# Fetched details for game ID: 36
# Fetched details for game ID: 16355
# Fetched details for game ID: 4249
# Fetched details for game ID: 4676
# Fetched details for game ID: 9545
# Fetched details for game ID: 258322
# Fetched details for game ID: 16191
# Fetched details for game ID: 19685
# Fetched details for game ID: 1299
# Fetched details for game ID: 9853
# Fetched details for game ID: 2434
# Fetched details for game ID: 3562
# Fetched details for game ID: 4612
# Fetched details for game ID: 1225
# Fetched details for game ID: 2778
# Fetched details for game ID: 2559
# Fetched details for game ID: 17599
# Fetched details for game ID: 3850
# Fetched details for game ID: 715
# Fetched details for game ID: 3651
# Platform 4 - Page 13 done.
# Fetched details for game ID: 3450
# Fetched details for game ID: 60179
# Fetched details for game ID: 17295
# Fetched details for game ID: 22789
# Fetched details for game ID: 20760
# Fetched details for game ID: 58585
# Fetched details for game ID: 516111
# Fetched details for game ID: 3251
# Fetched details for game ID: 17925
# Fetched details for game ID: 137
# Fetched details for game ID: 2239
# Fetched details for game ID: 4744
# Fetched details for game ID: 2354
# Fetched details for game ID: 123
# Fetched details for game ID: 13469
# Fetched details for game ID: 10049
# Fetched details for game ID: 28261
# Fetched details for game ID: 401805
# Fetched details for game ID: 4923
# Fetched details for game ID: 3772
# Fetched details for game ID: 19458
# Fetched details for game ID: 9465
# Fetched details for game ID: 14990
# Fetched details for game ID: 19309
# Fetched details for game ID: 3748
# Fetched details for game ID: 2913
# Fetched details for game ID: 323065
# Fetched details for game ID: 29173
# Fetched details for game ID: 2845
# Fetched details for game ID: 722
# Fetched details for game ID: 19284
# Fetched details for game ID: 7485
# Fetched details for game ID: 50677
# Fetched details for game ID: 22597
# Fetched details for game ID: 3268
# Fetched details for game ID: 18081
# Fetched details for game ID: 364806
# Fetched details for game ID: 18886
# Fetched details for game ID: 1322
# Fetched details for game ID: 9904
# Platform 4 - Page 14 done.
# Fetched details for game ID: 3494
# Fetched details for game ID: 22069
# Fetched details for game ID: 2390
# Fetched details for game ID: 2830
# Fetched details for game ID: 20980
# Fetched details for game ID: 13498
# Fetched details for game ID: 10900
# Fetched details for game ID: 12018
# Fetched details for game ID: 9979
# Fetched details for game ID: 4414
# Fetched details for game ID: 11228
# Fetched details for game ID: 3358
# Fetched details for game ID: 9741
# Fetched details for game ID: 23702
# Fetched details for game ID: 10125
# Fetched details for game ID: 2412
# Fetched details for game ID: 14989
# Fetched details for game ID: 10296
# Fetched details for game ID: 9494
# Fetched details for game ID: 3090
# Fetched details for game ID: 2767
# Fetched details for game ID: 7317
# Fetched details for game ID: 13273
# Fetched details for game ID: 19380
# Fetched details for game ID: 18184
# Fetched details for game ID: 2556
# Fetched details for game ID: 9744
# Fetched details for game ID: 22162
# Fetched details for game ID: 18726
# Fetched details for game ID: 11148
# Fetched details for game ID: 21736
# Fetched details for game ID: 19633
# Fetched details for game ID: 19439
# Fetched details for game ID: 236694
# Fetched details for game ID: 20569
# Fetched details for game ID: 401
# Fetched details for game ID: 10050
# Fetched details for game ID: 3468
# Fetched details for game ID: 122
# Fetched details for game ID: 9782
# Platform 4 - Page 15 done.
# Fetched details for game ID: 10327
# Fetched details for game ID: 46597
# Fetched details for game ID: 11567
# Fetched details for game ID: 29
# Fetched details for game ID: 27938
# Fetched details for game ID: 22938
# Fetched details for game ID: 9824
# Fetched details for game ID: 1830
# Fetched details for game ID: 11663
# Fetched details for game ID: 14072
# Fetched details for game ID: 427930
# Fetched details for game ID: 2139
# Fetched details for game ID: 2055
# Fetched details for game ID: 58698
# Fetched details for game ID: 11425
# Fetched details for game ID: 10537
# Fetched details for game ID: 12980
# Fetched details for game ID: 19560
# Fetched details for game ID: 10281
# Fetched details for game ID: 10436
# Fetched details for game ID: 99
# Fetched details for game ID: 23191
# Fetched details for game ID: 15860
# Fetched details for game ID: 10926
# Fetched details for game ID: 19369
# Fetched details for game ID: 10393
# Fetched details for game ID: 4602
# Fetched details for game ID: 4361
# Fetched details for game ID: 4477
# Fetched details for game ID: 9515
# Fetched details for game ID: 2131
# Fetched details for game ID: 244716
# Fetched details for game ID: 13570
# Fetched details for game ID: 19397
# Fetched details for game ID: 372576
# Fetched details for game ID: 13387
# Fetched details for game ID: 2889
# Fetched details for game ID: 17357
# Fetched details for game ID: 22508
# Fetched details for game ID: 19584
# Platform 4 - Page 16 done.
# Fetched details for game ID: 59023
# Fetched details for game ID: 4206
# Fetched details for game ID: 842
# Fetched details for game ID: 18287
# Fetched details for game ID: 339961
# Fetched details for game ID: 791638
# Fetched details for game ID: 12884
# Fetched details for game ID: 35561
# Fetched details for game ID: 13909
# Fetched details for game ID: 19568
# Fetched details for game ID: 4111
# Fetched details for game ID: 61961
# Fetched details for game ID: 18185
# Fetched details for game ID: 17158
# Fetched details for game ID: 9736
# Fetched details for game ID: 12662
# Fetched details for game ID: 12757
# Fetched details for game ID: 58640
# Fetched details for game ID: 906547
# Fetched details for game ID: 61176
# Fetched details for game ID: 2287
# Fetched details for game ID: 9495
# Fetched details for game ID: 31771
# Fetched details for game ID: 4520
# Fetched details for game ID: 20992
# Fetched details for game ID: 313843
# Fetched details for game ID: 5711
# Fetched details for game ID: 445442
# Fetched details for game ID: 17975
# Fetched details for game ID: 4483
# Fetched details for game ID: 16856
# Fetched details for game ID: 4186
# Fetched details for game ID: 16649
# Fetched details for game ID: 15861
# Fetched details for game ID: 13512
# Fetched details for game ID: 5706
# Fetched details for game ID: 3838
# Fetched details for game ID: 7439
# Fetched details for game ID: 28631
# Fetched details for game ID: 28615
# Platform 4 - Page 17 done.
# Fetched details for game ID: 13566
# Fetched details for game ID: 13525
# Fetched details for game ID: 5538
# Fetched details for game ID: 54491
# Fetched details for game ID: 17676
# Fetched details for game ID: 14211
# Fetched details for game ID: 58735
# Fetched details for game ID: 57908
# Fetched details for game ID: 2296
# Fetched details for game ID: 5678
# Fetched details for game ID: 887
# Fetched details for game ID: 10389
# Fetched details for game ID: 9871
# Fetched details for game ID: 50418
# Fetched details for game ID: 58754
# Fetched details for game ID: 17998
# Fetched details for game ID: 2639
# Fetched details for game ID: 3726
# Fetched details for game ID: 18449
# Fetched details for game ID: 4571
# Fetched details for game ID: 9831
# Fetched details for game ID: 11214
# Fetched details for game ID: 16543
# Fetched details for game ID: 295019
# Fetched details for game ID: 59197
# Fetched details for game ID: 3863
# Fetched details for game ID: 22790
# Fetched details for game ID: 3400
# Fetched details for game ID: 17179
# Fetched details for game ID: 966
# Fetched details for game ID: 4154
# Fetched details for game ID: 11887
# Fetched details for game ID: 965
# Fetched details for game ID: 13199
# Fetched details for game ID: 22961
# Fetched details for game ID: 10602
# Fetched details for game ID: 58758
# Fetched details for game ID: 46399
# Fetched details for game ID: 10724
# Fetched details for game ID: 9811
# Platform 4 - Page 18 done.
# Fetched details for game ID: 1612
# Fetched details for game ID: 37669
# Fetched details for game ID: 20466
# Fetched details for game ID: 47326
# Fetched details for game ID: 10056
# Fetched details for game ID: 13925
# Fetched details for game ID: 392019
# Fetched details for game ID: 10342
# Fetched details for game ID: 10545
# Fetched details for game ID: 14422
# Fetched details for game ID: 10980
# Fetched details for game ID: 4466
# Fetched details for game ID: 9997
# Fetched details for game ID: 3374
# Fetched details for game ID: 17545
# Fetched details for game ID: 9911
# Fetched details for game ID: 58890
# Fetched details for game ID: 29658
# Fetched details for game ID: 15851
# Fetched details for game ID: 441
# Fetched details for game ID: 50214
# Fetched details for game ID: 464
# Fetched details for game ID: 479694
# Fetched details for game ID: 28589
# Fetched details for game ID: 4031
# Fetched details for game ID: 19908
# Fetched details for game ID: 271
# Fetched details for game ID: 19655
# Fetched details for game ID: 9659
# Fetched details for game ID: 17854
# Fetched details for game ID: 339958
# Fetched details for game ID: 22397
# Fetched details for game ID: 16813
# Fetched details for game ID: 709
# Fetched details for game ID: 58835
# Fetched details for game ID: 16161
# Fetched details for game ID: 10665
# Fetched details for game ID: 10309
# Fetched details for game ID: 51687
# Fetched details for game ID: 46560
# Platform 4 - Page 19 done.
# Fetched details for game ID: 637477
# Fetched details for game ID: 28613
# Fetched details for game ID: 11164
# Fetched details for game ID: 23479
# Fetched details for game ID: 10023
# Fetched details for game ID: 43
# Fetched details for game ID: 22846
# Fetched details for game ID: 46508
# Fetched details for game ID: 17844
# Fetched details for game ID: 1073
# Fetched details for game ID: 2659
# Fetched details for game ID: 28418
# Fetched details for game ID: 58859
# Fetched details for game ID: 38965
# Fetched details for game ID: 11460
# Fetched details for game ID: 14156
# Fetched details for game ID: 28580
# Fetched details for game ID: 58637
# Fetched details for game ID: 14364
# Fetched details for game ID: 1726
# Fetched details for game ID: 10206
# Fetched details for game ID: 2894
# Fetched details for game ID: 13780
# Fetched details for game ID: 10355
# Fetched details for game ID: 442857
# Fetched details for game ID: 876
# Fetched details for game ID: 441738
# Fetched details for game ID: 19635
# Fetched details for game ID: 897
# Fetched details for game ID: 17736
# Fetched details for game ID: 3189
# Fetched details for game ID: 12108
# Fetched details for game ID: 58385
# Fetched details for game ID: 12130
# Fetched details for game ID: 5524
# Fetched details for game ID: 27
# Fetched details for game ID: 17818
# Fetched details for game ID: 46301
# Fetched details for game ID: 10028
# Fetched details for game ID: 28131
# Platform 4 - Page 20 done.
# Fetched details for game ID: 3751
# Fetched details for game ID: 366885
# Fetched details for game ID: 10039
# Fetched details for game ID: 486
# Fetched details for game ID: 17473
# Fetched details for game ID: 5995
# Fetched details for game ID: 3277
# Fetched details for game ID: 45763
# Fetched details for game ID: 28126
# Fetched details for game ID: 12850
# Fetched details for game ID: 10037
# Fetched details for game ID: 19628
# Fetched details for game ID: 3513
# Fetched details for game ID: 13926
# Fetched details for game ID: 11975
# Fetched details for game ID: 397473
# Fetched details for game ID: 12045
# Fetched details for game ID: 2119
# Fetched details for game ID: 257192
# Fetched details for game ID: 58806
# Fetched details for game ID: 558986
# Fetched details for game ID: 11729
# Fetched details for game ID: 4480
# Fetched details for game ID: 3134
# Fetched details for game ID: 3933
# Fetched details for game ID: 54
# Fetched details for game ID: 12022
# Fetched details for game ID: 18852
# Fetched details for game ID: 5544
# Fetched details for game ID: 4473
# Fetched details for game ID: 58389
# Fetched details for game ID: 9644
# Fetched details for game ID: 12761
# Fetched details for game ID: 58394
# Fetched details for game ID: 748414
# Fetched details for game ID: 384567
# Fetched details for game ID: 758
# Fetched details for game ID: 59611
# Fetched details for game ID: 13466
# Fetched details for game ID: 4962
# Platform 4 - Page 21 done.
# Fetched details for game ID: 59637
# Fetched details for game ID: 16723
# Fetched details for game ID: 41498
# Fetched details for game ID: 14331
# Fetched details for game ID: 10379
# Fetched details for game ID: 54492
# Fetched details for game ID: 11223
# Fetched details for game ID: 327219
# Fetched details for game ID: 9828
# Fetched details for game ID: 54629
# Fetched details for game ID: 1249
# Fetched details for game ID: 19640
# Fetched details for game ID: 490
# Fetched details for game ID: 12344
# Fetched details for game ID: 343597
# Fetched details for game ID: 28300
# Fetched details for game ID: 49225
# Fetched details for game ID: 10270
# Fetched details for game ID: 9880
# Fetched details for game ID: 43734
# Fetched details for game ID: 18712
# Fetched details for game ID: 1854
# Fetched details for game ID: 5403
# Fetched details for game ID: 447
# Fetched details for game ID: 16003
# Fetched details for game ID: 548036
# Fetched details for game ID: 12073
# Fetched details for game ID: 10108
# Fetched details for game ID: 326236
# Fetched details for game ID: 10390
# Fetched details for game ID: 10180
# Fetched details for game ID: 369157
# Fetched details for game ID: 11839
# Fetched details for game ID: 39277
# Fetched details for game ID: 17169
# Fetched details for game ID: 58085
# Fetched details for game ID: 10715
# Fetched details for game ID: 35613
# Fetched details for game ID: 1488
# Fetched details for game ID: 3226
# Platform 4 - Page 22 done.
# Fetched details for game ID: 17945
# Fetched details for game ID: 43078
# Fetched details for game ID: 22734
# Fetched details for game ID: 63904
# Fetched details for game ID: 18708
# Fetched details for game ID: 4192
# Fetched details for game ID: 29180
# Fetched details for game ID: 19151
# Fetched details for game ID: 440079
# Fetched details for game ID: 15857
# Fetched details for game ID: 44029
# Fetched details for game ID: 22865
# Fetched details for game ID: 4185
# Fetched details for game ID: 9768
# Fetched details for game ID: 12048
# Fetched details for game ID: 4057
# Fetched details for game ID: 19962
# Fetched details for game ID: 58921
# Fetched details for game ID: 10416
# Fetched details for game ID: 452642
# Fetched details for game ID: 51324
# Fetched details for game ID: 50678
# Fetched details for game ID: 14625
# Fetched details for game ID: 42060
# Fetched details for game ID: 10302
# Fetched details for game ID: 16014
# Fetched details for game ID: 295020
# Fetched details for game ID: 2828
# Fetched details for game ID: 10241
# Fetched details for game ID: 570074
# Fetched details for game ID: 16351
# Fetched details for game ID: 3987
# Fetched details for game ID: 16779
# Fetched details for game ID: 5689
# Fetched details for game ID: 1545
# Fetched details for game ID: 9459
# Fetched details for game ID: 284664
# Fetched details for game ID: 14230
# Fetched details for game ID: 463723
# Fetched details for game ID: 17013
# Platform 4 - Page 23 done.
# Fetched details for game ID: 1391
# Fetched details for game ID: 320
# Fetched details for game ID: 23302
# Fetched details for game ID: 40265
# Fetched details for game ID: 12279
# Fetched details for game ID: 4240
# Fetched details for game ID: 274767
# Fetched details for game ID: 2944
# Fetched details for game ID: 8278
# Fetched details for game ID: 15422
# Fetched details for game ID: 798
# Fetched details for game ID: 59695
# Fetched details for game ID: 2784
# Fetched details for game ID: 455532
# Fetched details for game ID: 28156
# Fetched details for game ID: 194
# Fetched details for game ID: 311
# Fetched details for game ID: 52330
# Fetched details for game ID: 44510
# Fetched details for game ID: 19166
# Fetched details for game ID: 2592
# Fetched details for game ID: 4125
# Fetched details for game ID: 2666
# Fetched details for game ID: 12760
# Fetched details for game ID: 324992
# Fetched details for game ID: 1165
# Fetched details for game ID: 366881
# Fetched details for game ID: 3336
# Fetched details for game ID: 10346
# Fetched details for game ID: 29236
# Fetched details for game ID: 10758
# Fetched details for game ID: 15713
# Fetched details for game ID: 10606
# Fetched details for game ID: 16344
# Fetched details for game ID: 35086
# Fetched details for game ID: 19409
# Fetched details for game ID: 3489
# Fetched details for game ID: 12323
# Fetched details for game ID: 58831
# Fetched details for game ID: 19615
# Platform 4 - Page 24 done.
# Fetched details for game ID: 17010
# Fetched details for game ID: 2925
# Fetched details for game ID: 12322
# Fetched details for game ID: 45109
# Fetched details for game ID: 17087
# Fetched details for game ID: 20511
# Fetched details for game ID: 22412
# Fetched details for game ID: 58325
# Fetched details for game ID: 481910
# Fetched details for game ID: 4724
# Fetched details for game ID: 5877
# Fetched details for game ID: 3580
# Fetched details for game ID: 3307
# Fetched details for game ID: 1820
# Fetched details for game ID: 4489
# Fetched details for game ID: 47
# Fetched details for game ID: 17092
# Fetched details for game ID: 19503
# Fetched details for game ID: 12648
# Fetched details for game ID: 17741
# Fetched details for game ID: 2822
# Fetched details for game ID: 427
# Fetched details for game ID: 3325
# Fetched details for game ID: 445430
# Fetched details for game ID: 12649
# Fetched details for game ID: 9906
# Fetched details for game ID: 3332
# Fetched details for game ID: 12319
# Fetched details for game ID: 579507
# Fetched details for game ID: 19436
# Fetched details for game ID: 1116
# Fetched details for game ID: 11407
# Fetched details for game ID: 1108
# Fetched details for game ID: 2234
# Fetched details for game ID: 47428
# Fetched details for game ID: 452635
# Fetched details for game ID: 12280
# Fetched details for game ID: 10088
# Fetched details for game ID: 1720
# Fetched details for game ID: 9697
# Platform 4 - Page 25 done.
# Fetched details for game ID: 55984
# Fetched details for game ID: 19237
# Fetched details for game ID: 9598
# Fetched details for game ID: 3843
# Fetched details for game ID: 52215
# Error fetching details for game ID 3877: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/3877?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 6530: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/6530?key=f65a6008ebf44d2face1535b1518c4f3
# Fetched details for game ID: 373504
# Fetched details for game ID: 16183
# Error fetching details for game ID 324994: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/324994?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 616697: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/616697?key=f65a6008ebf44d2face1535b1518c4f3
# Fetched details for game ID: 10579
# Fetched details for game ID: 13583
# Fetched details for game ID: 50273
# Fetched details for game ID: 12741
# Error fetching details for game ID 54718: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/54718?key=f65a6008ebf44d2face1535b1518c4f3
# Fetched details for game ID: 24619
# Fetched details for game ID: 51
# Fetched details for game ID: 17600
# Fetched details for game ID: 3767
# Fetched details for game ID: 327227
# Fetched details for game ID: 304953
# Fetched details for game ID: 13999
# Fetched details for game ID: 52384
# Fetched details for game ID: 13777
# Fetched details for game ID: 20826
# Fetched details for game ID: 4796
# Fetched details for game ID: 14929
# Fetched details for game ID: 3223
# Fetched details for game ID: 50839
# Fetched details for game ID: 58732
# Fetched details for game ID: 15604
# Fetched details for game ID: 700
# Fetched details for game ID: 244722
# Fetched details for game ID: 58782
# Fetched details for game ID: 3437
# Fetched details for game ID: 1320
# Fetched details for game ID: 13778
# Fetched details for game ID: 257252
# Fetched details for game ID: 16922
# Platform 4 - Page 26 done.
# Fetched details for game ID: 44641
# Fetched details for game ID: 28195
# Fetched details for game ID: 9845
# Fetched details for game ID: 703
# Fetched details for game ID: 14397
# Fetched details for game ID: 3044
# Fetched details for game ID: 2184
# Fetched details for game ID: 452645
# Fetched details for game ID: 13779
# Fetched details for game ID: 15221
# Fetched details for game ID: 16179
# Fetched details for game ID: 19482
# Fetched details for game ID: 12641
# Fetched details for game ID: 674
# Fetched details for game ID: 87
# Fetched details for game ID: 58295
# Fetched details for game ID: 6885
# Fetched details for game ID: 17604
# Fetched details for game ID: 23600
# Fetched details for game ID: 15712
# Fetched details for game ID: 13868
# Fetched details for game ID: 1559
# Fetched details for game ID: 17536
# Fetched details for game ID: 263608
# Fetched details for game ID: 11471
# Fetched details for game ID: 16118
# Fetched details for game ID: 4518
# Fetched details for game ID: 14689
# Fetched details for game ID: 9891
# Fetched details for game ID: 9066
# Fetched details for game ID: 19536
# Fetched details for game ID: 388308
# Fetched details for game ID: 52943
# Fetched details for game ID: 2074
# Fetched details for game ID: 50736
# Fetched details for game ID: 20156
# Fetched details for game ID: 20709
# Fetched details for game ID: 15932
# Fetched details for game ID: 41052
# Fetched details for game ID: 650605
# Platform 4 - Page 27 done.
# Fetched details for game ID: 487910
# Fetched details for game ID: 287337
# Fetched details for game ID: 2992
# Fetched details for game ID: 14336
# Fetched details for game ID: 16123
# Fetched details for game ID: 61741
# Fetched details for game ID: 7441
# Fetched details for game ID: 660
# Fetched details for game ID: 57896
# Fetched details for game ID: 3154
# Fetched details for game ID: 12092
# Fetched details for game ID: 30119
# Fetched details for game ID: 22798
# Fetched details for game ID: 9989
# Fetched details for game ID: 13404
# Fetched details for game ID: 332
# Fetched details for game ID: 2548
# Fetched details for game ID: 3834
# Fetched details for game ID: 19535
# Fetched details for game ID: 15365
# Fetched details for game ID: 28627
# Fetched details for game ID: 3416
# Fetched details for game ID: 1575
# Fetched details for game ID: 30445
# Fetched details for game ID: 5158
# Fetched details for game ID: 42592
# Fetched details for game ID: 303576
# Fetched details for game ID: 15764
# Fetched details for game ID: 16948
# Fetched details for game ID: 54122
# Fetched details for game ID: 16817
# Fetched details for game ID: 1077
# Error fetching details for game ID 3164: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/3164?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 17085: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/17085?key=f65a6008ebf44d2face1535b1518c4f3
# Fetched details for game ID: 21966
# Error fetching details for game ID 326253: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/326253?key=f65a6008ebf44d2face1535b1518c4f3
# Fetched details for game ID: 10547
# Error fetching details for game ID 9840: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/9840?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 18301: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/18301?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 19646: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/19646?key=f65a6008ebf44d2face1535b1518c4f3
# Platform 4 - Page 28 done.
# Fetched details for game ID: 5783
# Fetched details for game ID: 364942
# Fetched details for game ID: 3413
# Fetched details for game ID: 12606
# Fetched details for game ID: 2960
# Fetched details for game ID: 23037
# Fetched details for game ID: 19627
# Fetched details for game ID: 57607
# Fetched details for game ID: 8923
# Fetched details for game ID: 295001
# Fetched details for game ID: 16552
# Fetched details for game ID: 4023
# Fetched details for game ID: 3734
# Fetched details for game ID: 40104
# Fetched details for game ID: 2503
# Fetched details for game ID: 22123
# Fetched details for game ID: 53446
# Fetched details for game ID: 2359
# Fetched details for game ID: 19345
# Fetched details for game ID: 369158
# Fetched details for game ID: 10364
# Fetched details for game ID: 268446
# Fetched details for game ID: 28150
# Fetched details for game ID: 15852
# Fetched details for game ID: 49236
# Fetched details for game ID: 10638
# Fetched details for game ID: 7353
# Fetched details for game ID: 3923
# Fetched details for game ID: 3574
# Fetched details for game ID: 288796
# Fetched details for game ID: 326229
# Fetched details for game ID: 14612
# Fetched details for game ID: 58766
# Fetched details for game ID: 680
# Fetched details for game ID: 3214
# Fetched details for game ID: 18853
# Fetched details for game ID: 9877
# Fetched details for game ID: 18347
# Fetched details for game ID: 275641
# Fetched details for game ID: 40936
# Platform 4 - Page 29 done.
# Fetched details for game ID: 9538
# Fetched details for game ID: 4143
# Fetched details for game ID: 17698
# Fetched details for game ID: 16515
# Fetched details for game ID: 10520
# Fetched details for game ID: 4148
# Fetched details for game ID: 16255
# Fetched details for game ID: 10261
# Fetched details for game ID: 17713
# Fetched details for game ID: 16466
# Fetched details for game ID: 16683
# Fetched details for game ID: 22844
# Fetched details for game ID: 17564
# Fetched details for game ID: 4465
# Fetched details for game ID: 60817
# Fetched details for game ID: 16700
# Fetched details for game ID: 327260
# Fetched details for game ID: 1430
# Fetched details for game ID: 223331
# Fetched details for game ID: 494384
# Fetched details for game ID: 2760
# Fetched details for game ID: 18701
# Fetched details for game ID: 1808
# Fetched details for game ID: 473489
# Fetched details for game ID: 60545
# Fetched details for game ID: 12250
# Fetched details for game ID: 614954
# Fetched details for game ID: 22853
# Fetched details for game ID: 14447
# Fetched details for game ID: 16144
# Fetched details for game ID: 16263
# Fetched details for game ID: 35519
# Fetched details for game ID: 9969
# Fetched details for game ID: 29238
# Fetched details for game ID: 18700
# Fetched details for game ID: 17703
# Fetched details for game ID: 11676
# Fetched details for game ID: 14793
# Fetched details for game ID: 2422
# Fetched details for game ID: 12877
# Platform 4 - Page 30 done.
# Fetched details for game ID: 4241
# Fetched details for game ID: 34668
# Fetched details for game ID: 249954
# Fetched details for game ID: 12321
# Fetched details for game ID: 45745
# Fetched details for game ID: 10119
# Fetched details for game ID: 3187
# Fetched details for game ID: 5383
# Fetched details for game ID: 14290
# Fetched details for game ID: 13764
# Fetched details for game ID: 16294
# Fetched details for game ID: 2306
# Fetched details for game ID: 5001
# Fetched details for game ID: 11591
# Fetched details for game ID: 18785
# Fetched details for game ID: 2298
# Fetched details for game ID: 21558
# Fetched details for game ID: 58834
# Fetched details for game ID: 52178
# Fetched details for game ID: 61694
# Fetched details for game ID: 4901
# Fetched details for game ID: 27943
# Fetched details for game ID: 16760
# Fetched details for game ID: 427519
# Fetched details for game ID: 19502
# Fetched details for game ID: 431
# Fetched details for game ID: 40368
# Fetched details for game ID: 17728
# Fetched details for game ID: 49104
# Fetched details for game ID: 40645
# Fetched details for game ID: 22344
# Fetched details for game ID: 42064
# Fetched details for game ID: 3363
# Fetched details for game ID: 326239
# Fetched details for game ID: 3548
# Fetched details for game ID: 42920
# Fetched details for game ID: 18844
# Fetched details for game ID: 801032
# Fetched details for game ID: 16792
# Fetched details for game ID: 40646
# Platform 4 - Page 31 done.
# Fetched details for game ID: 3194
# Fetched details for game ID: 40648
# Fetched details for game ID: 2570
# Fetched details for game ID: 59346
# Fetched details for game ID: 3316
# Fetched details for game ID: 42230
# Fetched details for game ID: 58386
# Fetched details for game ID: 13833
# Fetched details for game ID: 326248
# Fetched details for game ID: 533
# Fetched details for game ID: 3993
# Fetched details for game ID: 58914
# Fetched details for game ID: 545015
# Fetched details for game ID: 15457
# Fetched details for game ID: 428555
# Fetched details for game ID: 14346
# Fetched details for game ID: 5615
# Fetched details for game ID: 6641
# Fetched details for game ID: 50576
# Fetched details for game ID: 662357
# Fetched details for game ID: 16253
# Fetched details for game ID: 1984
# Fetched details for game ID: 16262
# Fetched details for game ID: 7241
# Fetched details for game ID: 3727
# Fetched details for game ID: 14827
# Fetched details for game ID: 3219
# Fetched details for game ID: 15687
# Fetched details for game ID: 15017
# Fetched details for game ID: 11350
# Fetched details for game ID: 28859
# Fetched details for game ID: 21119
# Fetched details for game ID: 49874
# Fetched details for game ID: 1378
# Fetched details for game ID: 17795
# Fetched details for game ID: 507152
# Fetched details for game ID: 29218
# Fetched details for game ID: 46000
# Fetched details for game ID: 10400
# Fetched details for game ID: 58820
# Platform 4 - Page 32 done.
# Fetched details for game ID: 602224
# Fetched details for game ID: 10118
# Fetched details for game ID: 3775
# Fetched details for game ID: 9964
# Fetched details for game ID: 2647
# Fetched details for game ID: 14237
# Fetched details for game ID: 440081
# Fetched details for game ID: 4234
# Fetched details for game ID: 16168
# Fetched details for game ID: 12074
# Fetched details for game ID: 47204
# Fetched details for game ID: 43982
# Fetched details for game ID: 4521
# Fetched details for game ID: 22512
# Fetched details for game ID: 325094
# Fetched details for game ID: 881
# Fetched details for game ID: 337960
# Fetched details for game ID: 13350
# Fetched details for game ID: 1451
# Fetched details for game ID: 287342
# Fetched details for game ID: 18290
# Fetched details for game ID: 274756
# Fetched details for game ID: 401808
# Fetched details for game ID: 13843
# Fetched details for game ID: 366083
# Fetched details for game ID: 338386
# Fetched details for game ID: 16254
# Fetched details for game ID: 1241
# Fetched details for game ID: 19281
# Fetched details for game ID: 17650
# Fetched details for game ID: 17768
# Fetched details for game ID: 3121
# Fetched details for game ID: 3238
# Fetched details for game ID: 326238
# Fetched details for game ID: 9976
# Fetched details for game ID: 4493
# Fetched details for game ID: 52997
# Fetched details for game ID: 4813
# Fetched details for game ID: 727315
# Fetched details for game ID: 19377
# Platform 4 - Page 33 done.
# Fetched details for game ID: 21
# Fetched details for game ID: 89
# ...
# Fetched details for game ID: 20282
# Fetched details for game ID: 11799
# Fetched details for game ID: 995
# Platform 4 - Page 68 done.
# Fetched details for game ID: 426096
# Fetched details for game ID: 857690
# Fetched details for game ID: 9860
# Fetched details for game ID: 3340
# Fetched details for game ID: 47466
# Fetched details for game ID: 8098
# Fetched details for game ID: 19610
# Fetched details for game ID: 10166
# Fetched details for game ID: 13468
# Fetched details for game ID: 58769
# Fetched details for game ID: 11778
# Fetched details for game ID: 8813
# Fetched details for game ID: 30243
# Fetched details for game ID: 2284
# Fetched details for game ID: 372700
# Fetched details for game ID: 19608
# Fetched details for game ID: 23069
# Fetched details for game ID: 22228
# Fetched details for game ID: 275703
# Fetched details for game ID: 4582
# Fetched details for game ID: 5606
# Fetched details for game ID: 654591
# Fetched details for game ID: 59115
# Fetched details for game ID: 705002
# Fetched details for game ID: 371847
# Fetched details for game ID: 15311
# Fetched details for game ID: 304320
# Fetched details for game ID: 12720
# Fetched details for game ID: 14178
# Fetched details for game ID: 30198
# Fetched details for game ID: 16426
# Fetched details for game ID: 47379
# Fetched details for game ID: 61153
# Fetched details for game ID: 430275
# Fetched details for game ID: 23011
# Fetched details for game ID: 349557
# Fetched details for game ID: 11193
# Fetched details for game ID: 319132
# Fetched details for game ID: 14638
# Fetched details for game ID: 455515
# Platform 4 - Page 69 done.
# Fetched details for game ID: 672365
# Fetched details for game ID: 151232
# Fetched details for game ID: 18743
# Fetched details for game ID: 532168
# Fetched details for game ID: 3454
# Fetched details for game ID: 4183
# Fetched details for game ID: 10826
# Fetched details for game ID: 21503
# Fetched details for game ID: 4555
# Fetched details for game ID: 630676
# Fetched details for game ID: 1271
# Fetched details for game ID: 362874
# Fetched details for game ID: 16932
# Fetched details for game ID: 17807
# Fetched details for game ID: 58771
# Fetched details for game ID: 20848
# Fetched details for game ID: 304216
# Fetched details for game ID: 357891
# Fetched details for game ID: 861287
# Fetched details for game ID: 18399
# Fetched details for game ID: 19370
# Fetched details for game ID: 241088
# Fetched details for game ID: 5950
# Fetched details for game ID: 22702
# Fetched details for game ID: 12899
# Fetched details for game ID: 316859
# Fetched details for game ID: 19576
# Fetched details for game ID: 14520
# Fetched details for game ID: 10753
# Fetched details for game ID: 11548
# Fetched details for game ID: 59883
# Fetched details for game ID: 16503
# Fetched details for game ID: 9690
# Fetched details for game ID: 57918
# Fetched details for game ID: 14639
# Fetched details for game ID: 297287
# Fetched details for game ID: 19379
# Fetched details for game ID: 11484
# Fetched details for game ID: 17423
# Fetched details for game ID: 14473
# Platform 4 - Page 70 done.
# Fetched details for game ID: 58896
# Fetched details for game ID: 58312
# Fetched details for game ID: 236801
# Fetched details for game ID: 45691
# Fetched details for game ID: 21097
# Fetched details for game ID: 366110
# Fetched details for game ID: 59059
# Fetched details for game ID: 37751
# Fetched details for game ID: 367176
# Fetched details for game ID: 12201
# Fetched details for game ID: 1480
# Fetched details for game ID: 704730
# Fetched details for game ID: 18540
# Fetched details for game ID: 249994
# Fetched details for game ID: 59347
# Fetched details for game ID: 9651
# Fetched details for game ID: 15574
# Fetched details for game ID: 4618
# Fetched details for game ID: 647611
# Fetched details for game ID: 4903
# Fetched details for game ID: 15337
# Fetched details for game ID: 16868
# Fetched details for game ID: 22965
# Fetched details for game ID: 17450
# Fetched details for game ID: 707254
# Fetched details for game ID: 50616
# Fetched details for game ID: 1071
# Fetched details for game ID: 308098
# Fetched details for game ID: 8318
# Fetched details for game ID: 670693
# Fetched details for game ID: 29225
# Fetched details for game ID: 19236
# Fetched details for game ID: 471031
# Fetched details for game ID: 59350
# Fetched details for game ID: 19382
# Fetched details for game ID: 871264
# Fetched details for game ID: 38559
# Fetched details for game ID: 28539
# Fetched details for game ID: 367183
# Fetched details for game ID: 9385
# Platform 4 - Page 71 done.
# Fetched details for game ID: 13483
# Fetched details for game ID: 11403
# Fetched details for game ID: 494382
# Fetched details for game ID: 29069
# Fetched details for game ID: 3182
# Fetched details for game ID: 259883
# Fetched details for game ID: 19287
# Fetched details for game ID: 10179
# Fetched details for game ID: 12751
# Fetched details for game ID: 14936
# Fetched details for game ID: 11593
# Fetched details for game ID: 11706
# Fetched details for game ID: 561
# Fetched details for game ID: 18110
# Fetched details for game ID: 16008
# Fetched details for game ID: 42889
# Fetched details for game ID: 415171
# Fetched details for game ID: 58498
# Fetched details for game ID: 916
# Fetched details for game ID: 367044
# Fetched details for game ID: 3165
# Fetched details for game ID: 650604
# Fetched details for game ID: 11984
# Fetched details for game ID: 60546
# Fetched details for game ID: 2404
# Fetched details for game ID: 13008
# Fetched details for game ID: 322240
# Fetched details for game ID: 51584
# Fetched details for game ID: 16225
# Fetched details for game ID: 3467
# Fetched details for game ID: 21631
# Fetched details for game ID: 15553
# Fetched details for game ID: 25965
# Fetched details for game ID: 11098
# Fetched details for game ID: 59348
# Fetched details for game ID: 16431
# Fetched details for game ID: 44469
# Fetched details for game ID: 20850
# Fetched details for game ID: 60864
# Fetched details for game ID: 274761
# Platform 4 - Page 72 done.
# Fetched details for game ID: 10174
# Fetched details for game ID: 44735
# Fetched details for game ID: 10824
# Fetched details for game ID: 3917
# Fetched details for game ID: 23613
# Fetched details for game ID: 327210
# Fetched details for game ID: 13289
# Fetched details for game ID: 50775
# Fetched details for game ID: 19442
# Fetched details for game ID: 20358
# Fetched details for game ID: 22426
# Fetched details for game ID: 387345
# Fetched details for game ID: 627521
# Fetched details for game ID: 1237
# Fetched details for game ID: 42138
# Fetched details for game ID: 50919
# Fetched details for game ID: 16378
# Fetched details for game ID: 11383
# Fetched details for game ID: 28595
# Fetched details for game ID: 10304
# Fetched details for game ID: 11838
# Fetched details for game ID: 15079
# Fetched details for game ID: 21305
# Fetched details for game ID: 17808
# Fetched details for game ID: 15854
# Fetched details for game ID: 11728
# Fetched details for game ID: 21312
# Fetched details for game ID: 9656
# Fetched details for game ID: 18699
# Fetched details for game ID: 389851
# Fetched details for game ID: 13796
# Fetched details for game ID: 14503
# Fetched details for game ID: 17186
# Fetched details for game ID: 49382
# Fetched details for game ID: 327208
# Fetched details for game ID: 327232
# Fetched details for game ID: 4678
# Fetched details for game ID: 387329
# Fetched details for game ID: 323051
# Fetched details for game ID: 23669
# Platform 4 - Page 73 done.
# Fetched details for game ID: 9696
# Fetched details for game ID: 4679
# Fetched details for game ID: 518596
# Fetched details for game ID: 10607
# Fetched details for game ID: 14154
# Fetched details for game ID: 288747
# Fetched details for game ID: 13121
# Fetched details for game ID: 16178
# Fetched details for game ID: 21530
# Fetched details for game ID: 374507
# Fetched details for game ID: 17187
# Fetched details for game ID: 21668
# Fetched details for game ID: 257203
# Fetched details for game ID: 3640
# Fetched details for game ID: 16210
# Fetched details for game ID: 2770
# Fetched details for game ID: 9849
# Fetched details for game ID: 28448
# Fetched details for game ID: 12797
# Fetched details for game ID: 3861
# Fetched details for game ID: 423950
# Fetched details for game ID: 499
# Fetched details for game ID: 9504
# Fetched details for game ID: 10020
# Fetched details for game ID: 10928
# Fetched details for game ID: 17810
# Fetched details for game ID: 14096
# Fetched details for game ID: 3206
# Fetched details for game ID: 17538
# Fetched details for game ID: 19669
# Fetched details for game ID: 268363
# Fetched details for game ID: 19585
# Fetched details for game ID: 52336
# Fetched details for game ID: 16373
# Fetched details for game ID: 18342
# Fetched details for game ID: 262465
# Fetched details for game ID: 6315
# Fetched details for game ID: 846499
# Fetched details for game ID: 801567
# Fetched details for game ID: 62920
# Platform 4 - Page 74 done.
# Fetched details for game ID: 351436
# Fetched details for game ID: 11473
# Fetched details for game ID: 1602
# Fetched details for game ID: 2705
# Fetched details for game ID: 9726
# Fetched details for game ID: 2196
# Fetched details for game ID: 59094
# Fetched details for game ID: 17372
# Fetched details for game ID: 17082
# Fetched details for game ID: 49268
# Fetched details for game ID: 21113
# Fetched details for game ID: 257194
# Fetched details for game ID: 297322
# Fetched details for game ID: 257377
# Fetched details for game ID: 42047
# Fetched details for game ID: 16120
# Fetched details for game ID: 3323
# Fetched details for game ID: 5981
# Fetched details for game ID: 13657
# Fetched details for game ID: 484842
# Fetched details for game ID: 244869
# Fetched details for game ID: 261232
# Fetched details for game ID: 586054
# Fetched details for game ID: 13884
# Fetched details for game ID: 539
# Fetched details for game ID: 61442
# Fetched details for game ID: 19476
# Fetched details for game ID: 966349
# Fetched details for game ID: 2838
# Fetched details for game ID: 19455
# Fetched details for game ID: 18793
# Fetched details for game ID: 376929
# Fetched details for game ID: 364812
# Fetched details for game ID: 20120
# Fetched details for game ID: 4511
# Fetched details for game ID: 21098
# Fetched details for game ID: 481913
# Fetched details for game ID: 3035
# Fetched details for game ID: 290894
# Fetched details for game ID: 17780
# Platform 4 - Page 75 done.
# Fetched details for game ID: 21615
# Fetched details for game ID: 20986
# Fetched details for game ID: 263537
# Fetched details for game ID: 61536
# Fetched details for game ID: 13027
# Fetched details for game ID: 42857
# Fetched details for game ID: 20302
# Fetched details for game ID: 17793
# Fetched details for game ID: 58818
# Fetched details for game ID: 19080
# Fetched details for game ID: 3857
# Fetched details for game ID: 12410
# Fetched details for game ID: 9437
# Fetched details for game ID: 35358
# Fetched details for game ID: 21510
# Fetched details for game ID: 416811
# Fetched details for game ID: 45416
# Fetched details for game ID: 366884
# Fetched details for game ID: 375223
# Fetched details for game ID: 13114
# Fetched details for game ID: 14988
# Fetched details for game ID: 299545
# Fetched details for game ID: 274849
# Fetched details for game ID: 484939
# Fetched details for game ID: 730
# Fetched details for game ID: 11508
# Fetched details for game ID: 9678
# Fetched details for game ID: 681463
# Fetched details for game ID: 6508
# Fetched details for game ID: 7978
# Fetched details for game ID: 49498
# Fetched details for game ID: 16184
# Fetched details for game ID: 21808
# Fetched details for game ID: 616688
# Fetched details for game ID: 23214
# Fetched details for game ID: 7784
# Fetched details for game ID: 10204
# Fetched details for game ID: 15034
# Fetched details for game ID: 20109
# Fetched details for game ID: 1922
# Platform 4 - Page 76 done.
# Fetched details for game ID: 4471
# Fetched details for game ID: 369
# Fetched details for game ID: 19899
# Fetched details for game ID: 13280
# Fetched details for game ID: 11665
# Fetched details for game ID: 499331
# Fetched details for game ID: 60685
# Fetched details for game ID: 510699
# Fetched details for game ID: 8001
# Fetched details for game ID: 284763
# Fetched details for game ID: 284674
# Fetched details for game ID: 20723
# Fetched details for game ID: 14621
# Fetched details for game ID: 10811
# Fetched details for game ID: 384504
# Fetched details for game ID: 427653
# Fetched details for game ID: 21140
# Fetched details for game ID: 19703
# Fetched details for game ID: 62419
# Fetched details for game ID: 59640
# Fetched details for game ID: 40035
# Fetched details for game ID: 306147
# Fetched details for game ID: 979524
# Fetched details for game ID: 16716
# Fetched details for game ID: 17917
# Fetched details for game ID: 21322
# Fetched details for game ID: 50328
# Fetched details for game ID: 58765
# Fetched details for game ID: 21411
# Fetched details for game ID: 19046
# Fetched details for game ID: 22415
# Fetched details for game ID: 514902
# Fetched details for game ID: 18758
# Fetched details for game ID: 35314
# Fetched details for game ID: 301576
# Fetched details for game ID: 23341
# Fetched details for game ID: 20159
# Fetched details for game ID: 10121
# Fetched details for game ID: 22869
# Fetched details for game ID: 57666
# Platform 4 - Page 77 done.
# Fetched details for game ID: 28757
# Fetched details for game ID: 19445
# Fetched details for game ID: 1801
# Fetched details for game ID: 369237
# Fetched details for game ID: 32247
# Fetched details for game ID: 49950
# Fetched details for game ID: 349844
# Fetched details for game ID: 13776
# Fetched details for game ID: 48894
# Fetched details for game ID: 263587
# Fetched details for game ID: 38146
# Fetched details for game ID: 59641
# Fetched details for game ID: 18794
# Fetched details for game ID: 18795
# Fetched details for game ID: 275606
# Fetched details for game ID: 19678
# Fetched details for game ID: 845261
# Fetched details for game ID: 20041
# Fetched details for game ID: 407565
# Fetched details for game ID: 349109
# Fetched details for game ID: 47361
# Fetched details for game ID: 45737
# Fetched details for game ID: 2713
# Fetched details for game ID: 18797
# Fetched details for game ID: 58209
# Fetched details for game ID: 3163
# Fetched details for game ID: 16043
# Fetched details for game ID: 18796
# Fetched details for game ID: 5776
# Error fetching details for game ID 20995: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/20995?key=f65a6008ebf44d2face1535b1518c4f3
# Fetched details for game ID: 292080
# Error fetching details for game ID 301518: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/301518?key=f65a6008ebf44d2face1535b1518c4f3
# Fetched details for game ID: 14913
# Fetched details for game ID: 372505
# Error fetching details for game ID 330427: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/330427?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 16131: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/16131?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 10403: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/10403?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 10366: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/10366?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 49355: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/49355?key=f65a6008ebf44d2face1535b1518c4f3
# Error fetching details for game ID 244721: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games/244721?key=f65a6008ebf44d2face1535b1518c4f3
# Platform 4 - Page 78 done.
# Error fetching game list for platform 4 page 79: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games?key=f65a6008ebf44d2face1535b1518c4f3&platforms=4&page_size=40&page=79
# Error fetching game list for platform 5 page 1: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games?key=f65a6008ebf44d2face1535b1518c4f3&platforms=5&page_size=40&page=1
# Error fetching game list for platform 6 page 1: 502 Server Error: Bad Gateway for url: https://api.rawg.io/api/games?key=f65a6008ebf44d2face1535b1518c4f3&platforms=6&page_size=40&page=1
# Total detailed games fetched: (3099, 8)

# %%
# print first 5 rows
games_df.head()
# Out:
#    platform_id  game_id                              name   released  rating  \
# 0            4     3498                Grand Theft Auto V 2013-09-17    4.47
# 1            4     3328          The Witcher 3: Wild Hunt 2015-05-18    4.65
# 2            4     4200                          Portal 2 2011-04-18    4.59
# 3            4     4291  Counter-Strike: Global Offensive 2012-08-21    3.56
# 4            4     5286                Tomb Raider (2013) 2013-03-05    4.06
#
#    metacritic           genres  \
# 0        92.0           Action
# 1        92.0      Action, RPG
# 2        95.0  Shooter, Puzzle
# 3        81.0          Shooter
# 4        86.0           Action
#
#                                                 tags  \
# 0  Singleplayer, Steam Achievements, Multiplayer,...
# 1  Singleplayer, Full controller support, Atmosph...
# 2  Singleplayer, Steam Achievements, Multiplayer,...
# 3  Steam Achievements, Multiplayer, Full controll...
# 4  Singleplayer, Multiplayer, Full controller sup...
#
#                          name_mod
# 0              grand theft auto v
# 1         the witcher 3 wild hunt
# 2                        portal 2
# 3  counterstrike global offensive
# 4                tomb raider 2013

# %%
# info about data
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3099 entries, 0 to 3098
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   platform_id  3099 non-null   int32
#  1   game_id      3099 non-null   int32
#  2   name         3099 non-null   object
#  3   released     3089 non-null   datetime64[ns]
#  4   rating       3099 non-null   float64
#  5   metacritic   2118 non-null   float64
#  6   genres       3099 non-null   object
#  7   tags         3099 non-null   object
#  8   name_mod     3099 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(2), int32(2), object(3)
# memory usage: 264.4+ KB

# %%
# count of unique games
print(games_df["name"].value_counts())

# unquie games
print(games_df["name"].nunique())
# Out:
# name
# Grand Theft Auto V                            1
# NEOTOKYO                                      1
# Volgarr the Viking                            1
# Stubbs the Zombie in Rebel Without a Pulse    1
# Nuclear Dawn                                  1
#                                              ..
# PC Building Simulator                         1
# Wargroove                                     1
# Total War: WARHAMMER                          1
# LET IT DIE                                    1
# Fun with Ragdolls: The Game                   1
# Name: count, Length: 3099, dtype: int64
# 3099

# %%
# Clean game title
games_df["name_mod"] = games_df["name"].apply(text_preprocessing)
# remove games with 0 chars
games_df = games_df[games_df["name_mod"].str.len() > 0]
# convert Game Name Cleanded col to category
games_df["name_mod"] = games_df["name_mod"].astype("category")

# Last Played column as date
games_df["released"] = pd.to_datetime(games_df["released"])

# convert int64 columns into int32
int64_cols = games_df.select_dtypes(include='int64').columns
games_df[int64_cols] = games_df[int64_cols].astype('int32')

# %%
# save games_df optionally for later backup
games_df.to_csv("games.csv", index = False)

# %%
def clean_split_column(column):
    """
    Cleans and splits a column with comma-separated values into a list.
    Handles NaNs and strips whitespace.
    """
    return column.fillna('').apply(lambda x: [item.strip() for item in x.split(',') if item.strip()])

def encode_multilabel_column(df, column_name):
    """
    Applies MultiLabelBinarizer to a column of lists and returns the encoded DataFrame.
    """
    mlb = MultiLabelBinarizer()
    encoded = mlb.fit_transform(df[column_name])
    encoded_df = pd.DataFrame(encoded, columns=[f"{column_name}_{cls}" for cls in mlb.classes_], index=df.index)
    return encoded_df

# %%
games_df = pd.read_csv("games.csv")

# %%
# clean genres column
games_df['genres'] = clean_split_column(games_df['genres'])
# clean tags column
games_df['tags'] = clean_split_column(games_df['tags'])

# %%
# encode columns
genre_encoded = encode_multilabel_column(games_df, 'genres')
tag_encoded = encode_multilabel_column(games_df, 'tags')

# concatenate back to original DataFrame
clean_games = pd.concat([clean_games, genre_encoded, tag_encoded], axis=1)

# show columns
clean_games.columns
# Out:
# Index(['platform_id', 'game_id', 'name', 'released', 'rating', 'metacritic',
#        'name_mod', 'genres_Action', 'genres_Adventure', 'genres_Arcade',
#        ...
#        'tags_street racing', 'tags_tracks', 'tags_true exclusive',
#        'tags_unique', 'tags_vr mod', 'tags_w10 exclusive', 'tags_waves',
#        'tags_wizard', 'tags_wizards', 'tags_work'],
#       dtype='object', length=369)

# %%
# sort values by game_id and platform_id
clean_games = clean_games.sort_values(by = ["game_id", "platform_id"])
clean_games.head()
# Out:
#       platform_id  game_id                         name    released  rating  \
# 1309            4       21                       DiRT 4  2017-06-06    3.61
# 108             4       25  Middle-earth: Shadow of War  2017-09-27    3.85
# 1494            4       26                  Nex Machina  2017-06-19    3.90
# 795             4       27                         Pyre  2017-07-25    4.17
# 8               4       28        Red Dead Redemption 2  2018-10-26    4.59
#
#       metacritic                   name_mod  genres_Action  genres_Adventure  \
# 1309        78.0                     dirt 4              0                 0
# 108         82.0  middleearth shadow of war              1                 0
# 1494        89.0                nex machina              1                 0
# 795         84.0                       pyre              0                 1
# 8           96.0      red dead redemption 2              1                 0
#
#       genres_Arcade  ...  tags_street racing  tags_tracks  \
# 1309              0  ...                   0            0
# 108               0  ...                   0            0
# 1494              0  ...                   0            0
# 795               1  ...                   0            0
# 8                 0  ...                   0            0
#
#       tags_true exclusive  tags_unique  tags_vr mod  tags_w10 exclusive  \
# 1309                    0            0            0                   0
# 108                     0            0            0                   0
# 1494                    0            0            0                   0
# 795                     0            0            0                   0
# 8                       0            0            0                   0
#
#       tags_waves  tags_wizard  tags_wizards  tags_work
# 1309           0            0             0          0
# 108            0            0             0          0
# 1494           0            0             0          0
# 795            0            0             0          0
# 8              0            0             0          0
#
# [5 rows x 369 columns]

# %%
# Save preprocessed dataframe for later use
clean_games.to_csv("games_preprocessed.csv", index = False)

# %% [markdown]
# ## Search Engine based on Text similarity

# %%
# Load games data if exist
games_df = pd.read_csv("../data/games_preprocessed.csv")

# %%
print(games_df.isnull().sum())
games_df = games_df.dropna(subset = ["name_mod"])
print(games_df.isnull().sum())
# Out:
# platform_id            0
# game_id                0
# name                   0
# released              10
# rating                 0
#                       ..
# tags_w10 exclusive     0
# tags_waves             0
# tags_wizard            0
# tags_wizards           0
# tags_work              0
# Length: 369, dtype: int64
# platform_id            0
# game_id                0
# name                   0
# released              10
# rating                 0
#                       ..
# tags_w10 exclusive     0
# tags_waves             0
# tags_wizard            0
# tags_wizards           0
# tags_work              0
# Length: 369, dtype: int64

# %%
# instantiate object
vectorizer = TfidfVectorizer()
# apply it on games name
tfidf = vectorizer.fit_transform(games_df["name_mod"])

# %%
query = " grand    thieft auto   "
# preprocess query
cleaned_query = text_preprocessing(query)
print(cleaned_query)
# convert query to vector
query_vec = vectorizer.transform([cleaned_query])
# find similar items
similarities = cosine_similarity(query_vec, tfidf).flatten()
# print similarities
print(similarities)
# extract top 10 indices
indices = np.argpartition(similarities, -10)[-10:]
# final results similar to the query
results = games_df.iloc[indices]
# Out:
# grand thieft auto
# [0. 0. 0. ... 0. 0. 0.]

# %%
results
# Out:
#       platform_id  game_id                                               name  \
# 1033            4    10575                                  The Shrouded Isle
# 613             4     4414       Grand Theft Auto: Episodes from Liberty City
# 3069            4   709004  Grand Theft Auto: San Andreas – The Definitive...
# 619             4     4459                                Grand Theft Auto IV
# 72              4      430                        Grand Theft Auto: Vice City
# 69              4      416                      Grand Theft Auto: San Andreas
# 74              4      432                               Grand Theft Auto III
# 2451            4    52998                                   Grand Theft Auto
# 466             4     3498                                 Grand Theft Auto V
# 2450            4    52997                                 Grand Theft Auto 2
#
#         released  rating  metacritic  \
# 1033  2017-08-04    2.88         NaN
# 613   2009-10-29    4.11         NaN
# 3069  2021-11-11    3.06         NaN
# 619   2008-04-29    4.26        95.0
# 72    2002-10-27    4.45        94.0
# 69    2004-10-26    4.51        93.0
# 74    2001-10-22    4.15        93.0
# 2451  1997-10-21    3.86         NaN
# 466   2013-09-17    4.47        92.0
# 2450  1999-10-22    4.01        70.0
#
#                                                name_mod  genres_Action  \
# 1033                                  the shrouded isle              0
# 613         grand theft auto episodes from liberty city              1
# 3069  grand theft auto san andreas the definitive ed...              1
# 619                                 grand theft auto iv              1
# 72                           grand theft auto vice city              1
# 69                         grand theft auto san andreas              1
# 74                                 grand theft auto iii              1
# 2451                                   grand theft auto              1
# 466                                  grand theft auto v              1
# 2450                                 grand theft auto 2              1
#
#       genres_Adventure  genres_Arcade  ...  tags_street racing  tags_tracks  \
# 1033                 0              0  ...                   0            0
# 613                  0              0  ...                   0            0
# 3069                 1              0  ...                   0            0
# 619                  0              0  ...                   0            0
# 72                   0              0  ...                   0            0
# 69                   0              0  ...                   0            0
# 74                   0              0  ...                   0            0
# 2451                 0              0  ...                   0            0
# 466                  0              0  ...                   0            0
# 2450                 0              0  ...                   0            0
#
#       tags_true exclusive  tags_unique  tags_vr mod  tags_w10 exclusive  \
# 1033                    0            0            0                   0
# 613                     0            0            0                   0
# 3069                    0            0            0                   0
# 619                     0            0            0                   0
# 72                      0            0            0                   0
# 69                      0            0            0                   0
# 74                      0            0            0                   0
# 2451                    0            0            0                   0
# 466                     0            0            0                   0
# 2450                    0            0            0                   0
#
#       tags_waves  tags_wizard  tags_wizards  tags_work
# 1033           0            0             0          0
# 613            0            0             0          0
# 3069           0            0             0          0
# 619            0            0             0          0
# 72             0            0             0          0
# 69             0            0             0          0
# 74             0            0             0          0
# 2451           0            0             0          0
# 466            0            0             0          0
# 2450           0            0             0          0
#
# [10 rows x 369 columns]

# %%
def fetch_query(query, vectorizer):
    cleaned_query = text_preprocessing(query)
    # convert query to vector
    query_vec = vectorizer.transform([cleaned_query])
    # find similar items
    similarities = cosine_similarity(query_vec, tfidf).flatten()
    # extract top 10 indices
    indices = np.argpartition(similarities, -5)[-5:]
    # final results similar to the query
    results = games_df.iloc[indices]
    # if there are duplicate rows
    # results = results.sort_values(by = "rating", ascending = False)
    # return final results
    return results

# %%
fetch_query("batman", vectorizer)
# Out:
#       platform_id  game_id                         name    released  rating  \
# 2729            4   295001  Batman: The Telltale Series  2016-08-02    3.75
# 273             4     2235       Batman: Arkham Origins  2013-10-25    3.95
# 1569            4    16543                  LEGO Batman  2008-09-23    3.77
# 2188            4    28623          Batman: Arkham City  2011-10-18    4.42
# 416             4     3287        Batman: Arkham Knight  2015-06-23    4.24
#
#       metacritic                    name_mod  genres_Action  genres_Adventure  \
# 2729        79.0  batman the telltale series              0                 1
# 273         74.0       batman arkham origins              1                 0
# 1569        80.0                 lego batman              1                 0
# 2188        94.0          batman arkham city              1                 0
# 416         81.0        batman arkham knight              1                 0
#
#       genres_Arcade  ...  tags_street racing  tags_tracks  \
# 2729              0  ...                   0            0
# 273               0  ...                   0            0
# 1569              0  ...                   0            0
# 2188              0  ...                   0            0
# 416               0  ...                   0            0
#
#       tags_true exclusive  tags_unique  tags_vr mod  tags_w10 exclusive  \
# 2729                    0            0            0                   0
# 273                     0            0            0                   0
# 1569                    0            0            0                   0
# 2188                    0            0            0                   0
# 416                     0            0            0                   0
#
#       tags_waves  tags_wizard  tags_wizards  tags_work
# 2729           0            0             0          0
# 273            0            0             0          0
# 1569           0            0             0          0
# 2188           0            0             0          0
# 416            0            0             0          0
#
# [5 rows x 369 columns]
